# %% [markdown]
# # 조별 과제: 은하의 각종 물리량으로부터 은하 형태 구분
#
# 본 실습은 Horizon Run 5 시뮬레이션 중 특정 적색이동에서 나온 은하 목록에 대해, 각종 물리량으로부터 은하 형태를 구분하는 것이 목표입니다.

# %% [markdown]
# 데이터의 맨 윗줄을 읽어 보면 다음과 같습니다.

# %%
# Jupyter notebook에서 느낌표(!) 다음에 커맨드 명령어를 직접 입력하여 실행할 수 있다.
# !head -n5 galaxy_catalogue_296.txt
# Out:
# a= 0.615248018    H0= 68.4 km/s/Mpc  L=1048.58048 cMpc   Pure volume=  1.28216523e+07 cMpc^3
# ...

# %% [markdown]
# 위에 있는 수 많은 물리량 중, 우리가 은하 형태를 나타내는 파라메터로 사용할 값은 Vrot / Vsig 입니다.
#
# 참고로 각 물리량에 대한 설명은 아래와 같습니다.
# - x, y, z: 공변위치
# - Vx, Vy, Vz: 고유속도
# - Mstar, Mgas, Mcold: 별, 가스, 차가운 가스의 질량
# - SFR: 별 생성률
# - R1/2: 유효반경
# - Z: 중원소비율
# - u, g, r, i, z: u/g/r/i/z 필터로 관측한 광량
# - Vrot, Vsig: 회전속도, 속도분산
# - Lx, Ly, Lz: 각운동량
# - ...
